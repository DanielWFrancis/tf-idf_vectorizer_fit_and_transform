# %% [markdown]
# # tf-idf vectorizer fit and transform
#
# I experienced a bit of a breakthrough messing around with the scikit-learn’s tf-idf vectorizer under the guidance of my Springboard mentor. In this example I am working with data that I scraped from the Mercatus Center website. I originally scraped a corpus of over 5000 documents containing all published output, excluding charts, including multi-label duplicates. However, in this example I worked with a smaller subset of 27 documents to avoid having to wait 10 minutes for something to finish running.

# %% [markdown]
# ### Setting up
#
# The first cell of my jupyter notebook is imports and setting matplotlib inline:

# %%
from sklearn.datasets import load_files
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# %matplotlib inline

# %% [markdown]
# Then, I used the load_files function to load my multi-label corpus, which is just files placed in directories whose names are the label names:

# %%
# trainer = load_files('data')
trainer = load_files('data_short')

# %% [markdown]
# You can use the following two attributes of trainer to get an idea of what you have:

# %%
print(str(len(trainer.target_names)) + ' target names')
print(str(len(trainer.filenames)) + ' filenames')
# Out:
# 2 target names
# 27 filenames

# %% [markdown]
# Finally, we should initialize a dataframe and add a few useful columns to it.

# %%
df = pd.DataFrame()
df['filename'] = trainer.filenames
df['text'] = [open(f, 'r').read() for f in trainer.filenames]
df['label'] = [trainer.target_names[x] for x in trainer.target]
df['author'] = [x.split('__')[0].split('--')[0].split('/')[-1] for x in df['filename']]

# %% [markdown]
# ### Fitting the tf-idf vectorizer to your data
#
# Term frequency – inverse document frequency, or tf-idf, is a neat little statistic that tells you how important a particular word is for a document, relative to all the other documents in a corpus. As the name suggests, the formula is approximately the number of times the word appears in the document, divided by the number of times it appears in the entire corpus (the real math is here but you don't need it). Words like “and” will clearly have very low tf-idf scores, then, while a word like “finance” will have a very high tf-idf score in a finance article if the rest of the corpus is about cooking. This is nice, as it is a quantified way of telling us that there is something very special about this one article’s topic, compared with the rest of the articles!
#
# The first order of business is to initialize a tf-idf vectorizer, which we can then use to attack our corpus.

# %%
tfidf = TfidfVectorizer(min_df=3, max_df=0.9)

# %% [markdown]
# min_df indicates the minimum number of documents a word must be in to count - this is a way to avoid counting proper nouns and other words that do not tell us much about a document's topic. max_df indicates the maximum proportion of documents a word can be in before it counts - this is how we avoid counting words like "and", which would slow down our processing times and contribute little to understanding individual documents.
#
# Now we are ready to "fit" the vectorizer to our list of document texts, as stored in df['text']. Fitting is the process of converting every word in the corpus to a number, and storing these word-number pairs in a Python dictionary.

# %%
tfidf = tfidf.fit(df.text)

# %% [markdown]
# This was a bit of a breakthrough for me, as I never understood exactly what "fit" meant, despite probably reading a definition a dozen times. You can see your new dictionary by typing in the following:

# %%
tfidf.vocabulary_
# Out:
# {'licensing': 2162,
#  '81': 205,
#  'expert': 1484,
#  'deemed': 1092,
#  'effect': 1290,
#  'x9cuber': 4008,
#  'begin': 592,
#  'manner': 2253,
#  'seek': 3240,
#  '30': 136,
#  'sides': 3302,
#  'opposed': 2543,
#  'commuters': 857,
#  'manage': 2241,
#  'dulles': 1259,
#  'blocks': 620,
#  'entrepreneurs': 1374,
#  'own': 2589,
#  'carl': 710,
#  'cover': 1014,
#  'fears': 1553,
#  'structured': 3457,
#  'anyone': 443,
#  'lost': 2214,
#  'opportunity': 2541,
#  'x9351': 3917,
#  'expertise': 1485,
#  'viability': 3779,
#  'kind': 2087,
#  'same': 3192,
#  'calculations': 679,
#  'definition': 1099,
#  'occur': 2492,
#  'despite': 1145,
#  'forcing': 1623,
#  'results': 3114,
#  'canceled': 693,
#  'recession': 2974,
#  'regardless': 3010,
#  'ownership': 2593,
#  'final': 1578,
#  'medium': 2306,
#  'proposes': 2864,
#  'margin': 2262,
#  'lawmakers': 2122,
#  'day': 1066,
#  'reaction': 2948,
#  'jones': 2061,
#  'importantly': 1882,
#  'measurement': 2299,
#  'expected': 1470,
#  'carrier': 714,
#  'incorporation': 1911,
#  'could': 1000,
#  'banks': 571,
#  'produced': 2822,
#  'take': 3527,
#  'duration': 1260,
#  'persists': 2673,
#  'diego': 1170,
#  'indication': 1927,
#  'improve': 1888,
#  'tailored': 3526,
#  'era': 1388,
#  '44': 158,
#  'fallen': 1535,
#  'rivals': 3150,
#  'numerous': 2469,
#  'granted': 1739,
#  'world': 3880,
#  'cautious': 735,
#  'conference': 913,
#  'book': 629,
#  'electronic': 1304,
#  'signed': 3306,
#  'maintenance': 2234,
#  'potential': 2750,
#  '211': 120,
#  'compliance': 886,
#  'affect': 336,
#  'age': 346,
#  'object': 2471,
#  '203': 118,
#  'barrier': 575,
#  'so': 3343,
#  'x9ctoward': 4006,
#  'fatalities': 1547,
#  'sensible': 3257,
#  'everything': 1420,
#  'clear': 801,
#  'understand': 3705,
#  'die': 1169,
#  'managing': 2245,
#  'obama': 2470,
#  'rulemakings': 3174,
#  'whom': 3851,
#  'rely': 3044,
#  'giant': 1706,
#  'eu': 1406,
#  'citizens': 792,
#  'catastrophic': 724,
#  'editor': 1285,
#  'matthew': 2283,
#  'highly': 1805,
#  'house': 1829,
#  'critical': 1032,
#  'been': 588,
#  'call': 682,
#  'model': 2361,
#  '2007': 105,
#  'deregulating': 1130,
#  'narrow': 2406,
#  'costs': 999,
#  'approval': 463,
#  'large': 2110,
#  'waiting': 3804,
#  'collapse': 819,
#  'aviation': 552,
#  'undergoing': 3700,
#  'books': 630,
#  'easily': 1272,
#  'connecting': 924,
#  'promulgated': 2855,
#  'economic': 1275,
#  'filing': 1575,
#  'asymmetries': 516,
#  'consensus': 927,
#  'serves': 3271,
#  'proof': 2856,
#  'x9cin': 3986,
#  'pounds': 2753,
#  'longer': 2206,
#  '409': 154,
#  'lot': 2215,
#  'directing': 1183,
#  'relating': 3031,
#  'screen': 3222,
#  'owns': 2595,
#  'fundamental': 1670,
#  'trucking': 3669,
#  'gained': 1679,
#  'wind': 3863,
#  'capability': 697,
#  'reviewed': 3129,
#  'watch': 3816,
#  '84': 209,
#  'rule': 3172,
#  'another': 434,
#  'developing': 1162,
#  'toll': 3617,
#  'conspicuously': 941,
#  'continuously': 968,
#  'hard': 1776,
#  'whose': 3852,
#  'entering': 1363,
#  '92': 218,
#  'incentive': 1896,
#  '50': 165,
#  'speaking': 3371,
#  'carries': 716,
#  'firm': 1588,
#  'second': 3231,
#  'tend': 3556,
#  'external': 1505,
#  'minimal': 2338,
#  'findings': 1586,
#  'track': 3630,
#  'apparent': 447,
#  'being': 598,
#  'contracts': 970,
#  'district': 1218,
#  'suggesting': 3491,
#  'argues': 476,
#  'opened': 2528,
#  'erik': 1391,
#  'cruising': 1039,
#  'founded': 1641,
#  'raise': 2924,
#  'licensed': 2160,
#  'upward': 3738,
#  'modes': 2365,
#  'l9': 2100,
#  'preserving': 2781,
#  'cross': 1035,
#  'fagnant': 1524,
#  'closing': 811,
#  'high': 1799,
#  'vision': 3790,
#  'gives': 1709,
#  'were': 3835,
#  'recommendations': 2981,
#  '1966': 63,
#  'fix': 1593,
#  'guardian': 1758,
#  'them': 3577,
#  'framework': 1646,
#  'provisional': 2881,
#  'relationship': 3032,
#  'senate': 3254,
#  'chosen': 781,
#  'indicate': 1924,
#  'nonetheless': 2450,
#  'spend': 3381,
#  'terminals': 3561,
#  'tends': 3557,
#  'acts': 283,
#  'distance': 1210,
#  'competitor': 877,
#  'xa9': 4029,
#  'piece': 2690,
#  'needs': 2422,
#  'elements': 1306,
#  'joseph': 2063,
#  'prevented': 2787,
#  '85': 210,
#  'used': 3742,
#  'x94perhaps': 3956,
#  'purpose': 2894,
#  'was': 3813,
#  'relatively': 3035,
#  'subsidies': 3474,
#  'statement': 3411,
#  'x9cnew': 3988,
#  'sensitive': 3258,
#  'clearly': 802,
#  'formally': 1630,
#  'routine': 3168,
#  'consider': 931,
#  'delivery': 1107,
#  'recognize': 2977,
#  'controlled': 979,
#  'todd': 3615,
#  'plus': 2709,
#  'words': 3873,
#  'mail': 2229,
#  'activities': 280,
#  'against': 345,
#  'influenced': 1942,
#  'strict': 3446,
#  'thus': 3604,
#  'x94that': 3958,
#  'exist': 1456,
#  'answers': 436,
#  'say': 3203,
#  'boeing': 627,
#  'tracking': 3631,
#  'knowledge': 2093,
#  'british': 649,
#  'inc': 1895,
#  'sam': 3191,
#  'mechanisms': 2303,
#  'frame': 1645,
#  'certified': 747,
#  'conventional': 986,
#  'engineers': 1350,
#  'expressed': 1497,
#  'late': 2116,
#  'originated': 2564,
#  'active': 278,
#  'discovery': 1196,
#  'countless': 1007,
#  'purchase': 2890,
#  'borrow': 632,
#  'x94as': 3940,
#  'scarce': 3208,
#  'students': 3461,
#  'oregon': 2554,
#  'her': 1797,
#  'reports': 3065,
#  'whereby': 3845,
#  '1976': 72,
#  'x9can': 3970,
#  'x9d16': 4018,
#  'respects': 3094,
#  'keywords': 2084,
#  'people': 2654,
#  'convenience': 983,
#  'issued': 2036,
#  'reputation': 3070,
#  'recreational': 2988,
#  'playing': 2708,
#  'california': 681,
#  'obtain': 2486,
#  'purely': 2893,
#  'mass': 2274,
#  'distinct': 1212,
#  'organic': 2555,
#  'commuting': 859,
#  'appreciate': 457,
#  'although': 400,
#  'blame': 617,
#  '90': 215,
#  'heavy': 1790,
#  'happening': 1774,
#  'look': 2207,
#  'reduced': 2991,
#  'singapore': 3318,
#  'monitor': 2372,
#  'package': 2598,
#  'comparable': 862,
#  'problem': 2811,
#  '79': 202,
#  'devices': 1166,
#  'choosing': 780,
#  'residents': 3086,
#  'change': 758,
#  'detect': 1152,
#  'launch': 2120,
#  'environmental': 1378,
#  'suffice': 3486,
#  'sided': 3301,
#  'site': 3321,
#  'grew': 1747,
#  'through': 3602,
#  'measure': 2297,
#  'include': 1901,
#  'indicated': 1925,
#  'ground': 1749,
#  '2004': 102,
#  'equilibrium': 1383,
#  'facto': 1520,
#  'partner': 2618,
#  'form': 1628,
#  'details': 1151,
#  'x9357': 3920,
#  'society': 3346,
#  'terminal': 3560,
#  'operated': 2531,
#  'privately': 2806,
#  'end': 1340,
#  'climate': 804,
#  'holding': 1820,
#  'together': 3616,
#  'id': 1847,
#  'working': 3878,
#  'formal': 1629,
#  'however': 1834,
#  'following': 1617,
#  'pursuit': 2899,
#  'underlying': 3701,
#  'forbes': 1619,
#  'reasonable': 2963,
#  'difficult': 1176,
#  '787': 201,
#  'receiving': 2971,
#  'young': 4046,
#  'similar': 3311,
#  'confirms': 915,
#  'jurisdictions': 2072,
#  'should': 3293,
#  'x9358': 3921,
#  'joint': 2060,
#  'view': 3781,
#  'atus': 532,
#  'aerodynamic': 333,
#  'internet': 2001,
#  'account': 258,
#  'initial': 1950,
#  'our': 2569,
#  'expeditious': 1471,
#  'kockelman': 2096,
#  'quantitative': 2908,
#  'obviously': 2490,
#  'facebook': 1512,
#  'happened': 1773,
#  'influence': 1941,
#  'broader': 652,
#  'assess': 498,
#  'eliminate': 1309,
#  'off': 2498,
#  'puts': 2902,
#  'moves': 2393,
#  'bulletin': 661,
#  'statistics': 3417,
#  'interventions': 2010,
#  'payment': 2642,
#  'obstacle': 2484,
#  'x94is': 3953,
#  'building': 659,
#  'pay': 2640,
#  'ban': 567,
#  'seemingly': 3244,
#  'transfer': 3641,
#  'docs': 1225,
#  'buses': 670,
#  '2017': 115,
#  'pattern': 2637,
#  'college': 827,
#  'valuable': 3755,
#  'lead': 2125,
#  'talk': 3533,
#  'philadelphia': 2684,
#  'greatest': 1744,
#  'allow': 385,
#  'supreme': 3508,
#  'x9d7': 4025,
#  'date': 1063,
#  'measurable': 2296,
#  'implications': 1878,
#  'ridesharing': 3140,
#  'single': 3319,
#  'infrastructure': 1947,
#  'knowing': 2092,
#  'miles': 2331,
#  'theatlantic': 3575,
#  'revenue': 3125,
#  '1988': 83,
#  'guiding': 1763,
#  'training': 3637,
#  'moore': 2378,
#  'came': 686,
#  'five': 1592,
#  'reduce': 2990,
#  'careful': 707,
#  'equipped': 1385,
#  'strong': 3451,
#  'risky': 3149,
#  'switch': 3521,
#  'san': 3195,
#  'professor': 2833,
#  'practice': 2757,
#  'countries': 1008,
#  'x9c': 3967,
#  'realize': 2957,
#  'airspace': 368,
#  'aren': 472,
#  'such': 3483,
#  'remote': 3050,
#  'expanded': 1463,
#  'meeting': 2308,
#  'attacks': 519,
#  'objections': 2472,
#  'supply': 3503,
#  'x935': 3916,
#  'reaches': 2946,
#  'only': 2525,
#  'reasoning': 2965,
#  'commerce': 842,
#  'equally': 1381,
#  'patterns': 2638,
#  'driving': 1252,
#  'roads': 3153,
#  'parties': 2616,
#  'family': 1539,
#  'discuss': 1198,
#  'life': 2163,
#  '3434': 142,
#  'decisions': 1084,
#  'steps': 3425,
#  'lobbying': 2193,
#  'december': 1080,
#  'concludes': 903,
#  'jurisdiction': 2071,
#  'implemented': 1875,
#  'domestic': 1232,
#  'partly': 2617,
#  'assistance': 505,
#  'indicators': 1929,
#  'impacts': 1869,
#  'term': 3559,
#  'preliminary': 2773,
#  'humans': 1841,
#  'wages': 3802,
#  'startups': 3408,
#  'measured': 2298,
#  'manufactured': 2255,
#  'after': 343,
#  'x9cwhat': 4010,
#  'peltzman': 2651,
#  'acquiring': 271,
#  'computers': 893,
#  'delays': 1105,
#  'department': 1118,
#  'procedure': 2814,
#  'problems': 2813,
#  'politically': 2721,
#  'passage': 2625,
#  'applied': 454,
#  'issues': 2037,
#  'smartphone': 3340,
#  'campuses': 689,
#  '1991': 87,
#  'pedestrian': 2649,
#  'comes': 837,
#  '10': 11,
#  'according': 256,
#  'changed': 759,
#  'shifts': 3288,
#  'claim': 796,
#  'land': 2105,
#  'x9382': 3930,
#  'immediately': 1866,
#  'relative': 3034,
#  'worth': 3885,
#  '700': 191,
#  'target': 3534,
#  'independent': 1921,
#  'enterprise': 1364,
#  'republished': 3069,
#  'growing': 1754,
#  'policies': 2716,
#  'scandal': 3207,
#  'takeoffs': 3530,
#  'anticipate': 439,
#  'advance': 316,
#  'imperfections': 1872,
#  'necessary': 2419,
#  'candidate': 694,
#  'informational': 1945,
#  'appropriate': 461,
#  'fails': 1528,
#  '520': 169,
#  'prosperity': 2867,
#  'adds': 300,
#  'assumes': 511,
#  'difficulty': 1177,
#  'persons': 2677,
#  'gauge': 1687,
#  'elgar': 1307,
#  'fourth': 1643,
#  'secure': 3237,
#  'easier': 1271,
#  'huge': 1839,
#  'benefits': 606,
#  'school': 3217,
#  'innovation': 1958,
#  'corrected': 994,
#  'hardware': 1777,
#  'html': 1836,
#  'geographic': 1698,
#  'southern': 3368,
#  'request': 3072,
#  'extensive': 1503,
#  '53': 170,
#  '66': 186,
#  'outlined': 2574,
#  'compensation': 872,
#  'effects': 1294,
#  'always': 405,
#  '1986': 81,
#  'frequent': 1657,
#  'traveler': 3653,
#  'shift': 3287,
#  'mandates': 2249,
#  'handling': 1770,
#  'those': 3593,
#  'breaches': 642,
#  'staff': 3395,
#  'exaggerated': 1432,
#  'x9cwho': 4013,
#  'welcome': 3831,
#  'st': 3393,
#  'singular': 3320,
#  '37': 148,
#  'inefficient': 1938,
#  'telephone': 3554,
#  'ongoing': 2523,
#  'assessments': 501,
#  'eliminated': 1310,
#  'convention': 985,
#  'keeping': 2079,
#  'legitimate': 2146,
#  'entire': 1365,
#  'entrants': 1371,
#  'application': 452,
#  'mechanism': 2302,
#  '67': 187,
#  'increased': 1913,
#  'spread': 3388,
#  'continuing': 966,
#  'advanced': 317,
#  'complaint': 879,
#  'massive': 2276,
#  'learned': 2132,
#  'objectives': 2474,
#  'attribute': 529,
#  'dc': 1068,
#  'most': 2383,
#  'quantify': 2907,
#  'whether': 3846,
#  'identified': 1852,
#  'rachel': 2919,
#  'taxpayers': 3544,
#  'popular': 2728,
#  'carrying': 718,
#  'face': 1511,
#  'ex': 1429,
#  'taxis': 3543,
#  '42': 156,
#  'causing': 733,
#  'solve': 3352,
#  'interpretation': 2004,
#  'opposition': 2544,
#  'pace': 2597,
#  'new': 2435,
#  'season': 3228,
#  'bureaucrats': 668,
#  'percent': 2657,
#  'network': 2430,
#  'notably': 2455,
#  'struggling': 3459,
#  'team': 3547,
#  'pittsburgh': 2693,
#  'process': 2819,
#  '70': 190,
#  'exposed': 1494,
#  'flaws': 1595,
#  'jan': 2045,
#  'paris': 2607,
#  'technologies': 3552,
#  'columbia': 830,
#  'x9323': 3905,
#  'failures': 1530,
#  'employ': 1325,
#  'accommodate': 253,
#  'gasoline': 1685,
#  'technica': 3549,
#  'adapt': 287,
#  'way': 3818,
#  'suggested': 3490,
#  'pulled': 2889,
#  'inform': 1943,
#  'civil': 794,
#  'amendment': 408,
#  'overnight': 2583,
#  'flows': 1607,
#  'varied': 3762,
#  '703': 192,
#  'timely': 3609,
#  'surface': 3510,
#  'takeoff': 3529,
#  'demand': 1108,
#  'perceived': 2656,
#  'referred': 2998,
#  'insufficient': 1978,
#  'location': 2197,
#  'omitted': 2517,
#  'clarify': 798,
#  'scenarios': 3210,
#  'martin': 2271,
#  'margins': 2264,
#  '94': 220,
#  'series': 3266,
#  'flights': 1602,
#  'suggest': 3489,
#  'restrictive': 3109,
#  'advancement': 318,
#  'orders': 2552,
#  'self': 3253,
#  '2008': 106,
#  'law': 2121,
#  'predicts': 2766,
#  'instance': 1970,
#  'conducts': 912,
#  'ticket': 3605,
#  'primary': 2796,
#  'united': 3719,
#  '1973': 69,
#  'february': 1557,
#  'announced': 430,
#  'nevertheless': 2434,
#  'climb': 805,
#  'come': 836,
#  'mandatory': 2251,
#  'failure': 1529,
#  '143': 37,
#  'bureaucratic': 667,
#  'select': 3250,
#  'counter': 1004,
#  'formulate': 1633,
#  'market': 2266,
#  'dataset': 1062,
#  'variation': 3760,
#  'tax': 3538,
#  'adjacent': 302,
#  'background': 564,
#  'inspection': 1967,
#  'bay': 582,
#  'x9d26': 4021,
#  'carbon': 705,
#  'beforehand': 590,
#  'advertising': 328,
#  'actively': 279,
#  'javier': 2048,
#  'inevitable': 1939,
#  'flown': 1606,
#  'expenditure': 1472,
#  'parameters': 2606,
#  'distracted': 1215,
#  'stop': 3433,
#  'ups': 3737,
#  'henry': 1796,
#  'exactly': 1431,
#  'services': 3273,
#  'urban': 3739,
#  'specialization': 3373,
#  'my': 2402,
#  'collection': 825,
#  'four': 1642,
#  'systems': 3524,
#  'extending': 1500,
#  'distributed': 1216,
#  'analog': 417,
#  'measures': 2300,
#  'twice': 3678,
#  'covered': 1016,
#  'contributing': 976,
#  'temperature': 3555,
#  'airplanes': 365,
#  'council': 1001,
#  'alan': 373,
#  'scrutiny': 3224,
#  'gps': 1733,
#  'incidents': 1900,
#  'certify': 748,
#  '120': 25,
#  'statute': 3419,
#  'germany': 1702,
#  'idea': 1848,
#  'car': 704,
#  'google': 1723,
#  'analysis': 419,
#  'charles': 768,
#  'contemporary': 958,
#  'damage': 1052,
#  'played': 2707,
#  'exciting': 1447,
#  'gross': 1748,
#  'mandated': 2248,
#  'read': 2949,
#  'air': 359,
#  'days': 1067,
#  'x9348': 3915,
#  'undermine': 3702,
#  'additional': 294,
#  'what': 3838,
#  'continued': 964,
#  'real': 2953,
#  'spillover': 3384,
#  'granting': 1740,
#  'viable': 3780,
#  'appears': 451,
#  'unknown': 3722,
#  'cut': 1047,
#  'strongest': 3453,
#  '34': 141,
#  'catch': 725,
#  'commercialization': 844,
#  '04': 5,
#  'represents': 3068,
#  'means': 2293,
#  'vs': 3798,
#  'x9cwhen': 4011,
#  'overview': 2586,
#  'credit': 1027,
#  'burden': 663,
#  'possibility': 2745,
#  'guide': 1760,
#  'status': 3418,
#  'if': 1856,
#  'branches': 640,
#  'restricting': 3106,
#  'utilize': 3750,
#  'requested': 3073,
#  'legalize': 2142,
#  'putting': 2903,
#  'expense': 1474,
#  'ford': 1624,
#  'metropolitan': 2321,
#  '300': 137,
#  'chris': 782,
#  'really': 2959,
#  'tinbergen': 3612,
#  'money': 2370,
#  'attributable': 528,
#  'emerged': 1318,
#  'sufficient': 3487,
#  'magnitude': 2227,
#  'tribune': 3660,
#  'done': 1234,
#  '95': 221,
#  'illegal': 1861,
#  'primarily': 2795,
#  'impose': 1883,
#  'x9cself': 4000,
#  'body': 626,
#  'adam': 286,
#  'x9chas': 3982,
#  'keep': 2078,
#  'resolved': 3089,
#  'globe': 1712,
#  'bureau': 666,
#  'leadership': 2128,
#  'table': 3525,
#  'wired': 3866,
#  'phase': 2681,
#  'james': 2044,
#  'regard': 3008,
#  'internal': 1999,
#  'barriers': 576,
#  'me': 2290,
#  'geography': 1699,
#  'explicitly': 1491,
#  'inherent': 1948,
#  'pilot': 2691,
#  'cato': 728,
#  'wrong': 3892,
#  'controversial': 982,
#  'clifford': 803,
#  'morning': 2381,
#  'effectively': 1292,
#  'supposed': 3507,
#  'top': 3623,
#  'goods': 1722,
#  'when': 3842,
#  'neither': 2428,
#  'will': 3858,
#  'olson': 2516,
#  'perspective': 2678,
#  'research': 3081,
#  'cutting': 1048,
#  'create': 1021,
#  'office': 2504,
#  'steering': 3422,
#  'valley': 3754,
#  'submitted': 3470,
#  'deployment': 1127,
#  'except': 1441,
#  'degrees': 1102,
#  'provide': 2875,
#  'spectrum': 3378,
#  'assessed': 499,
#  'reporting': 3064,
#  'necessarily': 2418,
#  'employed': 1326,
#  'sharing': 3286,
#  'maximum': 2286,
#  'electric': 1303,
#  'future': 1677,
#  'nobel': 2445,
#  'core': 989,
#  'found': 1639,
#  'dedicated': 1091,
#  'interpret': 2003,
#  'quite': 2914,
#  'crashed': 1019,
#  'taxation': 3539,
#  'responsible': 3101,
#  'x9d': 4016,
#  'argued': 475,
#  'combination': 832,
#  'substantially': 3478,
#  'george': 1700,
#  'get': 1703,
#  'productivity': 2829,
#  'scholars': 3215,
#  'arguing': 477,
#  'micromanage': 2326,
#  'nearby': 2416,
#  'story': 3437,
#  'policy': 2717,
#  'knows': 2095,
#  '59': 178,
#  '2014': 112,
#  'innovative': 1960,
#  'carriage': 713,
#  'begins': 594,
#  'preferences': 2771,
#  'successful': 3482,
#  'explore': 1492,
#  'violate': 3786,
#  'examined': 1435,
#  'micro': 2325,
#  'attract': 527,
#  'slower': 3334,
#  'static': 3414,
#  'morrison': 2382,
#  'present': 2778,
#  'london': 2204,
#  'possibilities': 2744,
#  'exceptions': 1443,
#  'pricing': 2794,
#  'center': 737,
#  'trying': 3675,
#  'references': 2997,
#  'advocate': 331,
#  'total': 3627,
#  'abilities': 231,
#  'proceed': 2816,
#  'cannot': 695,
#  'federally': 1560,
#  'frequently': 1658,
#  'requests': 3074,
#  'expand': 1462,
#  'preemptive': 2767,
#  'ibid': 1846,
#  'undermined': 3703,
#  '1992': 88,
#  'realities': 2955,
#  'procedures': 2815,
#  'identify': 1854,
#  'production': 2827,
#  'property': 2859,
#  'still': 3429,
#  'happen': 1772,
#  'brian': 644,
#  'explained': 1488,
#  'impossible': 1887,
#  'showing': 3296,
#  'workers': 3876,
#  'topic': 3624,
#  'took': 3620,
#  'risk': 3147,
#  'built': 660,
#  'pays': 2644,
#  '900': 216,
#  'runs': 3179,
#  'renewal': 3053,
#  'essential': 1395,
#  'held': 1791,
#  'fleet': 1596,
#  'compares': 867,
#  'buy': 674,
#  'onboard': 2518,
#  'consideration': 934,
#  'maintain': 2231,
#  'rights': 3142,
#  'charged': 765,
#  'examination': 1433,
#  'x9cthis': 4003,
#  'attempted': 521,
#  'gdp': 1689,
#  'started': 3405,
#  'generation': 1696,
#  'abatement': 230,
#  '1975': 71,
#  'possibly': 2747,
#  'makers': 2238,
#  'rand': 2928,
#  'expectations': 1469,
#  '57': 176,
#  '09': 10,
#  'implement': 1873,
#  'virtually': 3788,
#  'experimentation': 1482,
#  'applications': 453,
#  'draw': 1246,
#  'sectors': 3236,
#  'smart': 3338,
#  'riders': 3137,
#  'appropriately': 462,
#  '1995': 91,
#  'side': 3300,
#  'good': 1721,
#  'choices': 778,
#  'ryan': 3182,
#  'los': 2210,
#  'desirable': 1142,
#  'deregulated': 1129,
#  'joan': 2055,
#  'discover': 1195,
#  'fundamentally': 1671,
#  'share': 3283,
#  'rarely': 2934,
#  'x9cwhy': 4014,
#  'las': 2114,
#  'am': 406,
#  'crossing': 1036,
#  'nationwide': 2410,
#  'currently': 1043,
#  'acceptance': 246,
#  'arises': 481,
#  '35': 143,
#  'scope': 3221,
#  'action': 276,
#  'carefully': 708,
#  'reduction': 2994,
#  'operator': 2536,
#  'impacting': 1868,
#  'ability': 232,
#  'science': 3218,
#  'observed': 2480,
#  'possess': 2742,
#  'proper': 2857,
#  'disruptive': 1209,
#  'latest': 2118,
#  'aims': 358,
#  'oxford': 2596,
#  'online': 2524,
#  'believe': 600,
#  'rulemaking': 3173,
#  'met': 2316,
#  'accident': 251,
#  'description': 1136,
#  'x94such': 3957,
#  'comparatively': 864,
#  'dot': 1236,
#  'dollar': 1230,
#  'six': 3325,
#  'controlling': 980,
#  ...}

# %% [markdown]
# Pretty cool stuff!

# %% [markdown]
# ### Using tf-idf transform
#
# My goal here is simply educational, so I haven't done anything too fancy yet. At the advice of my Springboard mentor, I created some "topic" lists with some key terms that could define each topic, then calculated each document's cumulative tf-idf score for those topic words. You can then put these list of scores in the dataframe we created and do some cool stuff!
#
# First, creating the topic lists:

# %%
finance_words = ['finance', 'economics', 'financial', 'stocks', 'dollars', 'equity', 'bond', 'bonds', 'commodity']
tech_words = ['technology','tech','machine','computer','software','internet','hardware']

# %% [markdown]
# These are pretty good guesses of what might be in the average Mercatus paper. I completely made these lists up, so don't take this as a literal topic mapping!
#
# Next, we need to loop through a transform() of the text column in our dataframe, df['text']. Each x in the tfidf.transform(df['text']) object below represents a document in our corpus, repesented as a matrix mapping numbers in our tfidf.vocabulary_ to tf-idf scores. In this way, each x represents a tf-idf score for each word in a document. Pretty cool!

# %%
topic = []
for x in tfidf.transform(df['text']):
    fin = pd.np.sum([x[(0, tfidf.vocabulary_[w])] for w in tfidf.vocabulary_ if w in finance_words])
    tec = pd.np.sum([x[(0, tfidf.vocabulary_[w])] for w in tfidf.vocabulary_ if w in tech_words])
    topic.append([fin, tec])
    
df_topic = pd.DataFrame(topic, columns=['finance','tech'])

# %% [markdown]
# The body of this for loop defines a fin and tec variable, each of which are the sum of tf-idf scores for financial and tech words that appear in that particular document. We then take these two numbers and append them as a pair to the topic array that we initialized in the beginning of this code block. Once the for loop runs through every document in our transform, we can make a dataframe with this list of pairs as two columns, 'finance' and 'tech'.

# %% [markdown]
# ### Plotting the results
#
# What we have now is a dataframe called df_topic that has two columns with some very cool data: scores for how related each document is to the topics of finance and technology, as we defined them in our finance_words and tech_words lists above.
#
# This is perfect for a scatterplot! As usual, pandas makes the task very simple:

# %%
df_topic.plot.scatter(x='finance', y='tech', xlim=(0,0.31), ylim=(0,0.31))
None

# %% [markdown]
# Here we had to define what the x-axis and y-axis should be, along with some limits on those axes. The result is pretty cool! As we can see, every paper seems to have at least a little something to say about technology, but many papers have absolutely nothing to do with finance. However, there is definitely a skew towards finance-related papers, with one paper having a large focus on the topic.

# %% [markdown]
# ### Conclusion
#
# Obviously this is only modestly useful in application, but the exercise gave me a sense of the nuts and bolts of tf-idf fits and transforms work. For more insight, I suggest creating a transform() and storing it in a variable so that you can play around with the results. Something like this:

# %%
tf_transform = tfidf.transform(df['text'])

# %% [markdown]
# will allow you to peak into the x's that we iterated through earlier:

# %%
for x in tf_transform[26]:
    print(x)
    print(type(x))
# Out:
#   (0, 4050)	0.000561620252722
#   (0, 4047)	0.000623366773583
#   (0, 4044)	0.00119691770959
#   (0, 4041)	0.000398972569864
#   (0, 4039)	0.00153604606193
#   (0, 4038)	0.000712634422823
#   (0, 4037)	0.00815168986069
#   (0, 4036)	0.000660316525757
#   (0, 4035)	0.130179903749
#   (0, 4034)	0.000815168986069
#   (0, 4027)	0.00655920038579
#   (0, 4026)	0.965160079506
#   (0, 4016)	0.0295688866921
#   (0, 4006)	0.00301368986083
#   (0, 4002)	0.00248873396781
#   (0, 3999)	0.000815168986069
#   (0, 3996)	0.000815168986069
#   (0, 3993)	0.000815168986069
#   (0, 3991)	0.000702971884209
#   (0, 3985)	0.000815168986069
#   (0, 3983)	0.00124673354717
#   (0, 3981)	0.000815168986069
#   (0, 3978)	0.00140594376842
#   (0, 3977)	0.000815168986069
#   (0, 3974)	0.00059077478235
#   :	:
#   (0, 76)	0.00140594376842
#   (0, 74)	0.00132063305151
#   (0, 70)	0.000815168986069
#   (0, 64)	0.00163033797214
#   (0, 60)	0.00163033797214
#   (0, 55)	0.000815168986069
#   (0, 53)	0.00215782280549
#   (0, 51)	0.00172625824439
#   (0, 50)	0.00258938736658
#   (0, 46)	0.00239383541918
#   (0, 41)	0.00230406909289
#   (0, 39)	0.000815168986069
#   (0, 35)	0.00239383541918
#   (0, 31)	0.00129469368329
#   (0, 28)	0.000753422465208
#   (0, 24)	0.00199486284932
#   (0, 21)	0.000753422465208
#   (0, 19)	0.00159589027946
#   (0, 17)	0.000702971884209
#   (0, 13)	0.000660316525757
#   (0, 12)	0.000797945139728
#   (0, 11)	0.00427580653694
#   (0, 5)	0.000702971884209
#   (0, 1)	0.00165915597854
#   (0, 0)	0.000702971884209
# <class 'scipy.sparse.csr.csr_matrix'>
